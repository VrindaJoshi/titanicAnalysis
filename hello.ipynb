# %%
import pandas as pd
import numpy as np
data = pd.read_csv('titanic3.csv')

data.replace('?', np.nan, inplace = True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols = 5, figsize = (30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.drop('home.dest', inplace=True, axis=1)
data.drop('name', inplace=True, axis=1)
data.drop('embarked', inplace=True, axis=1)
data.drop('cabin', inplace=True, axis=1)
data.drop('ticket', inplace=True, axis=1)
data.drop('boat', inplace=True, axis=1)

# %%
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[['survived']]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055512
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# body            NaN
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 6s 3ms/step - loss: 0.6923 - accuracy: 0.5718
# Epoch 2/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6900 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6862 - accuracy: 0.5885
# Epoch 4/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6791 - accuracy: 0.6938
# Epoch 5/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6673 - accuracy: 0.7596
# Epoch 6/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6508 - accuracy: 0.7703
# Epoch 7/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6315 - accuracy: 0.7727
# Epoch 8/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6111 - accuracy: 0.7799
# Epoch 9/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5923 - accuracy: 0.7763
# Epoch 10/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5763 - accuracy: 0.7739
# Epoch 11/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5636 - accuracy: 0.7727
# Epoch 12/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5516 - accuracy: 0.7679
# Epoch 13/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5422 - accuracy: 0.7679
# Epoch 14/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5325 - accuracy: 0.7679
# Epoch 15/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5239 - accuracy: 0.7715
# Epoch 16/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5156 - accuracy: 0.7763
# Epoch 17/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5084 - accuracy: 0.7751
# Epoch 18/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5028 - accuracy: 0.7763
# Epoch 19/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4963 - accuracy: 0.7775
# Epoch 20/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4913 - accuracy: 0.7847
# Epoch 21/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4863 - accuracy: 0.7883
# Epoch 22/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4825 - accuracy: 0.7823
# Epoch 23/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4787 - accuracy: 0.7847
# Epoch 24/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4758 - accuracy: 0.7859
# Epoch 25/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4726 - accuracy: 0.7835
# Epoch 26/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4698 - accuracy: 0.7787
# Epoch 27/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4675 - accuracy: 0.7847
# Epoch 28/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4658 - accuracy: 0.7847
# Epoch 29/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4645 - accuracy: 0.7823
# Epoch 30/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4617 - accuracy: 0.7847
# Epoch 31/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4606 - accuracy: 0.7871
# Epoch 32/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4592 - accuracy: 0.7883
# Epoch 33/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4580 - accuracy: 0.7871
# Epoch 34/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4573 - accuracy: 0.7883
# Epoch 35/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4566 - accuracy: 0.7883
# Epoch 36/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4559 - accuracy: 0.7871
# Epoch 37/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4554 - accuracy: 0.7883
# Epoch 38/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4551 - accuracy: 0.7895
# Epoch 39/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4547 - accuracy: 0.7859
# Epoch 40/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4540 - accuracy: 0.7919
# Epoch 41/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4544 - accuracy: 0.7895
# Epoch 42/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4537 - accuracy: 0.7859
# Epoch 43/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4534 - accuracy: 0.7907
# Epoch 44/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4535 - accuracy: 0.7883
# Epoch 45/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4530 - accuracy: 0.7883
# Epoch 46/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4529 - accuracy: 0.7883
# Epoch 47/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4531 - accuracy: 0.7847
# Epoch 48/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4530 - accuracy: 0.7847
# Epoch 49/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4530 - accuracy: 0.7883
# Epoch 50/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4529 - accuracy: 0.7919

# %%
y_pred = np.rint(model.predict(X_test).flatten())
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 7/7 [==============================] - 0s 3ms/step
# 0.3875598086124402
